# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

fla = pd.read_csv('Florida_2.csv')
# fla.head()

# %%
sic = fla.loc[:,"NaicsCode":"NaicsDescription"]
sic
# Out:
#        NaicsCode                                   NaicsDescription
# 0         423120  Motor Vehicle Supplies and New Parts Merchant ...
# 1         713990      All Other Amusement and Recreation Industries
# 2         335311  Power, Distribution, and Specialty Transformer...
# 3         453220                 Gift, Novelty, and Souvenir Stores
# 4         541110                                 Offices of Lawyers
# 5         722211                        Limited-Service Restaurants
# 6         621111  Offices of Physicians (except Mental Health Sp...
# 7         541110                                 Offices of Lawyers
# 8         423820  Farm and Garden Machinery and Equipment Mercha...
# 9         722211                        Limited-Service Restaurants
# 10        541410                           Interior Design Services
# 11        238290               Other Building Equipment Contractors
# 12        624120  Services for the Elderly and Persons with Disa...
# ...
