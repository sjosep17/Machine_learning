# %%
import warnings
warnings.simplefilter('ignore')

# %%
# Read the csv file into a pandas DataFrame

fla = pd.read_csv('Florida_2.csv')
fla.head()
# Out:
#                          BorrName                     BorrStreet  \
# 0                    TARCA, INC..            3754 NW 54TH STREET
# 1        Around the Clock Fitness           1242 SW Pine Island.
# 2  Integrated Metering Systems, I  11701 South Belcher Road, Sui
# 3  Loving Enterprises Inc and 2 P          7885 Boca Ciega Drive
# 4  Lawrence J. Roberts & Associat          249 Catalonia Avenue.
#
#            BorrCity BorrState  BorrZip  BorrID LoanStatus  GrossApproval  \
# 0             MIAMI        FL    33142     308     CHGOFF        1900000
# 1        Cape coral        FL    33991    8127        PIF         521800
# 2             Largo        FL    33773    4025        PIF          40800
# 3  SAINT PETERSBURG        FL    33706    7228        PIF         332000
# 4      Coral gables        FL    33134    1508     EXEMPT         225000
#
#    SBAGuarantee  PctOfGuarantee   ...     NaicsCode  \
# 0       1425000            0.75   ...        423120
# 1        469620            0.90   ...        713990
# 2         34680            0.85   ...        335311
# 3        249000            0.75   ...        453220
# 4        112500            0.50   ...        541110
#
#                                     NaicsDescription  JobsSupported  \
# 0  Motor Vehicle Supplies and New Parts Merchant ...              5
# 1      All Other Amusement and Recreation Industries             20
# 2  Power, Distribution, and Specialty Transformer...             23
# 3                 Gift, Novelty, and Souvenir Stores             21
# 4                                 Offices of Lawyers              3
#
#   DeliveryMethod                   subpgmdesc  \
# 0         OTH 7A                     Guaranty
# 1            PLP                     Guaranty
# 2            PLP                     Guaranty
# 3            PLP                     Guaranty
# 4     SBA EXPRES  FA$TRK (Small Loan Express)
#
#                               BankName          BankStreet      BankCity  \
# 0                            TotalBank       100 SE 2nd St         MIAMI
# 1  Newtek Small Business Finance, Inc.  1981 Marcus Avenue  LAKE SUCCESS
# 2                         Synovus Bank       1148 Broadway      COLUMBUS
# 3       PNC Bank, National Association    222 Delaware Ave    WILMINGTON
# 4                            TotalBank       100 SE 2nd St         MIAMI
#
#    BankState  BankZip
# 0         FL    33131
# 1         NY    11042
# 2         GA    31901
# 3         DE    19801
# 4         FL    33131
#
# [5 rows x 37 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data1 = pd.read_csv('Florida_5.csv')

data1.drop(data1.columns[[2]], axis=1, inplace=True)

data1.tail()
# Out:
#                              BorrName  BorrID  GrossApproval  SBAGuarantee  \
# 15132      Advanced Family Care, Inc.   17748         100000         50000
# 15133  Arcila Radiology Consulting, P   17749          50000         25000
# 15134                     Blinc, Inc.   17750        1750000       1499925
# 15135            Ana M. Houston, Inc.   17751          20000         10000
# 15136                  Milner's, Inc.   17752          35000         17500
#
#        PctOfGuarantee  InterestRate  TermMonths  ApprovalFiscalYear  \
# 15132          0.5000          7.75          84                2010
# 15133          0.5000          9.75          84                2010
# 15134          0.8571          6.00         120                2010
# 15135          0.5000          9.75          60                2010
# 15136          0.5000          9.75          84                2010
#
#       ApprovalDate DisbursementDate      ...       Leverage COFiscalYear  \
# 15132       8/5/10           8/5/10      ...            4.0            0
# 15133       6/8/10           6/8/10      ...            4.0            0
# 15134      5/24/10           8/1/10      ...            4.0            0
# 15135      4/30/10           5/1/10      ...            4.0            0
# 15136       4/5/10           4/5/10      ...            4.0            0
#
#        COAmount  PrinBalanceCollected  PctOfPrinColl  CODate  \
# 15132         0              100000.0            1.0       0
# 15133         0               50000.0            1.0       0
# 15134         0             1750000.0            1.0       0
# 15135         0               20000.0            1.0       0
# 15136         0               35000.0            1.0       0
#
#        DaysRemainingAtCO  MonthsRemainingAtCO  NaicsCode JobsSupported
# 15132                  0                    0     621111             5
# 15133                  0                    0     621399             1
# 15134                  0                    0     325620            13
# 15135                  0                    0     115116             3
# 15136                  0                    0     561730            13
#
# [5 rows x 24 columns]

# %%
X = data1.iloc[:, :3].values
y = data1.iloc[:, 15].values
