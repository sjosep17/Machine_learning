# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

fla = pd.read_csv('Florida_2.csv')
fla.head()
# Out:
#                          BorrName                     BorrStreet  \
# 0                    TARCA, INC..            3754 NW 54TH STREET
# 1        Around the Clock Fitness           1242 SW Pine Island.
# 2  Integrated Metering Systems, I  11701 South Belcher Road, Sui
# 3  Loving Enterprises Inc and 2 P          7885 Boca Ciega Drive
# 4  Lawrence J. Roberts & Associat          249 Catalonia Avenue.
#
#            BorrCity BorrState  BorrZip  BorrID LoanStatus  GrossApproval  \
# 0             MIAMI        FL    33142     308     CHGOFF        1900000
# 1        Cape coral        FL    33991    8127        PIF         521800
# 2             Largo        FL    33773    4025        PIF          40800
# 3  SAINT PETERSBURG        FL    33706    7228        PIF         332000
# 4      Coral gables        FL    33134    1508     EXEMPT         225000
#
#    SBAGuarantee  PctOfGuarantee   ...     NaicsCode  \
# 0       1425000            0.75   ...        423120
# ...

# %%
fla.corr()
# Out:
#                        BorrZip    BorrID  GrossApproval  SBAGuarantee  \
# BorrZip               1.000000 -0.011141       0.021308      0.020373
# BorrID               -0.011141  1.000000       0.050410      0.053166
# GrossApproval         0.021308  0.050410       1.000000      0.994351
# SBAGuarantee          0.020373  0.053166       0.994351      1.000000
# PctOfGuarantee        0.034226  0.018945       0.303418      0.337999
# InterestRate         -0.066152 -0.081250      -0.342449     -0.340474
# TermMonths            0.058260  0.046447       0.450038      0.437010
# ApprovalFiscalYear    0.027121 -0.086432       0.071109      0.062264
# Days2Funded          -0.025972  0.005445      -0.006113     -0.004355
# Status               -0.024614 -0.330870      -0.077507     -0.074426
# DebtCoverage         -0.023663  0.132147      -0.034960     -0.025736
# Leverage             -0.008490 -0.220925      -0.042568     -0.041799
# ...

# %%
# fla.dropna()
# len(fla)
# fla.fillna(0, inplace=True)
# fla.head()

# %%
# X used "LoanStatus", "SBAGuarantee", "GrossApproval", "NaicsCode", "DebtCoverage", "Leverage", "PctOfGuarantee",

X = fla[["GrossApproval", "PctOfGuarantee", "PctOfPrinColl", "DebtCoverage", "Leverage", "LoanStatus"]]
y = fla["SBAGuarantee"]
print(X.shape, y.shape)

#.values.reshape(-1, 1)
# Out:
# (15137, 6) (15137,)

# %%
# data = X.copy()

data_binary_encoded = pd.get_dummies(fla, columns=["LoanStatus"])
data_binary_encoded.head()
# Out:
#                          BorrName                     BorrStreet  \
# 0                    TARCA, INC..            3754 NW 54TH STREET
# 1        Around the Clock Fitness           1242 SW Pine Island.
# 2  Integrated Metering Systems, I  11701 South Belcher Road, Sui
# 3  Loving Enterprises Inc and 2 P          7885 Boca Ciega Drive
# 4  Lawrence J. Roberts & Associat          249 Catalonia Avenue.
#
#            BorrCity BorrState  BorrZip  BorrID  GrossApproval  SBAGuarantee  \
# 0             MIAMI        FL    33142     308        1900000       1425000
# 1        Cape coral        FL    33991    8127         521800        469620
# 2             Largo        FL    33773    4025          40800         34680
# 3  SAINT PETERSBURG        FL    33706    7228         332000        249000
# 4      Coral gables        FL    33134    1508         225000        112500
#
#    PctOfGuarantee  InterestRate       ...                         subpgmdesc  \
# ...

# %%
from sklearn.model_selection import train_test_split

X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=57)

X_train.head()
# Out:
#        GrossApproval  PctOfGuarantee  PctOfPrinColl  DebtCoverage  Leverage  \
# 6240          132000            0.85           0.30          1.00      4.00
# 771            15000            0.50           0.30          1.25      3.75
# 5269           15000            0.50           0.30          1.00      4.00
# 14288         238000            0.75           0.35          1.50      3.50
# 8306         1188000            0.75           0.30          1.40      5.00
#
#        LoanStatus_CHGOFF  LoanStatus_COMMIT  LoanStatus_EXEMPT  LoanStatus_PIF
# 6240                   0                  0                  1               0
# 771                    0                  0                  1               0
# 5269                   0                  0                  1               0
# 14288                  0                  0                  1               0
# 8306                   0                  0                  1               0

# %%
# from sklearn.preprocessing import StandardScaler
# X_scaler = StandardScaler().fit(X_train)
# y_scaler = StandardScaler().fit(y_train)

# %%
# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)
# y_train_scaled = y_scaler.transform(y_train)
# y_test_scaled = y_scaler.transform(y_test)

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)


axes1.set_title("Original Data")


maxx = X_train["DebtCoverage"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)





def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)


axes1.scatter(X_train["DebtCoverage"], y_train)

# %%
plt.show()

# %%
# plt.savefig("FLA_TrainTestSplit.jpg")

# %%
fla.corr()
# Out:
#                        BorrZip    BorrID  GrossApproval  SBAGuarantee  \
# BorrZip               1.000000 -0.011141       0.021308      0.020373
# BorrID               -0.011141  1.000000       0.050410      0.053166
# GrossApproval         0.021308  0.050410       1.000000      0.994351
# SBAGuarantee          0.020373  0.053166       0.994351      1.000000
# PctOfGuarantee        0.034226  0.018945       0.303418      0.337999
# InterestRate         -0.066152 -0.081250      -0.342449     -0.340474
# TermMonths            0.058260  0.046447       0.450038      0.437010
# ApprovalFiscalYear    0.027121 -0.086432       0.071109      0.062264
# Days2Funded          -0.025972  0.005445      -0.006113     -0.004355
# Status               -0.024614 -0.330870      -0.077507     -0.074426
# DebtCoverage         -0.023663  0.132147      -0.034960     -0.025736
# Leverage             -0.008490 -0.220925      -0.042568     -0.041799
# ...

# %%
# X = pd.get_dummies(fla[["GrossApproval", "SBAGuaranteed"]])
# y = fla["COAmount"].values.reshape(-1, 1)
# X.head()

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# from sklearn.preprocessing import StandardScaler
# X_scaler = StandardScaler().fit(X_train)
# y_scaler = StandardScaler().fit(y_train)

# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)
# y_train_scaled = y_scaler.transform(y_train)
# y_test_scaled = y_scaler.transform(y_test)

# %%
# # Plot the results 
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# model.fit(X_train_scaled, y_train_scaled)
# plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="orange", label="Training Data")
# plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="purple", label="Testing Data")
# plt.legend()
# plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
# plt.title("Residual Plot")
# plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="orange", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="purple", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Projected .....")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

predictions = model.predict(X_test)
MSE = mean_squared_error(y_test, predictions)
r2 = model.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 4182418714.1974335, R2: 0.9898253464102632

# %%
# predict_CO = model.predict(X_test)
# for x in predict_CO:
#         if x[0]>100000:
#             print(x)

# %%
# y_test

# %%
# plt.savefig("FLA_lr.jpg")

# %%
import statsmodels.api as sm

# %%
X = fla[["GrossApproval", "SBAGuarantee" ,"PctOfGuarantee", "PctOfPrinColl", "DebtCoverage", "Leverage"]]
y = fla["SBAGuarantee"]


results = sm.OLS(y,X.astype(float)).fit()
#       = sm.OLS(y, X.astype(float)).fit()
#sm.add_constant(X))
# data = X.copy()



print( results.summary())

plt.scatter(X,y)

X_plot = np.linspace(0,1,15137)

plt.plot(X_plot, X_plot*results.params[0] + results.params[1])

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           SBAGuarantee   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.457e+32
# Date:                Wed, 11 Jul 2018   Prob (F-statistic):               0.00
# Time:                        20:23:01   Log-Likelihood:             2.8404e+05
# No. Observations:               15137   AIC:                        -5.681e+05
# Df Residuals:                   15131   BIC:                        -5.680e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# GrossApproval  -7.218e-18   1.71e-16     -0.042      0.966   -3.43e-16    3.29e-16
# ...
